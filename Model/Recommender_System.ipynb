# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import os

# %%
tourist_attraction = pd.read_excel('Tourist Attraction_List.xlsx')
tourist_attraction.head(10)
# Out:
#    place_id                         name             category  latitude  \
# 0         1         4 Brahma Statue Arts               Patung -7.247284
# 1         2  Adventure Land Romokalisari        Tujuan Wisata -7.198610
# 2         3         Alun - Alun Surabaya        Tujuan Wisata -7.263864
# 3         4                  Apsari Park                Taman -7.263635
# 4         5              Arca Joko Dolog  Bangunan Bersejarah -7.264916
# 5         6         Benteng Kedung Cowek  Bangunan Bersejarah -7.211604
# 6         7  Blockbuster Museum Surabaya               Museum -7.247754
# 7         8                 Bungkul Park           Taman Kota -7.291347
# 8         9                Cultural Hall        Gedung Konser -7.264086
# 9        10     Danau Angsa Pakuwon City                Taman -7.272880
#
#     longitude  rating  reviews_count
# 0  112.801081     4.3            681
# 1  112.664771     4.6            604
# 2  112.745306     4.8           8470
# 3  112.742562     4.6           7116
# 4  112.742777     4.6            925
# 5  112.781074     4.5            799
# 6  112.779573     4.7            546
# 7  112.739822     4.6          54683
# 8  112.745432     4.8            488
# 9  112.806698     4.4            915

# %%
tourist_attraction.isna().sum()
# Out:
# place_id         0
# name             0
# category         0
# latitude         0
# longitude        0
# rating           0
# reviews_count    0
# dtype: int64

# %%
tourist_attraction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   place_id       75 non-null     int64
#  1   name           75 non-null     object
#  2   category       75 non-null     object
#  3   latitude       75 non-null     float64
#  4   longitude      75 non-null     float64
#  5   rating         75 non-null     float64
#  6   reviews_count  75 non-null     int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 4.2+ KB

# %%
user_rating = pd.read_excel('Transformed User Rating Tempat Wisata.xlsx')
user_rating.head(10)
# Out:
#    user_id  place_id  rating
# 0        5         1       4
# 1        5        12       5
# 2        5        19       4
# 3        5        45       5
# 4        5        62       4
# 5        6         1       5
# 6        6        20       5
# 7        6        24       5
# 8        6        27       4
# 9        6        63       4

# %%
user_rating.isna().sum()
# Out:
# user_id     0
# place_id    0
# rating      0
# dtype: int64

# %%
user_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7417 entries, 0 to 7416
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   7417 non-null   int64
#  1   place_id  7417 non-null   int64
#  2   rating    7417 non-null   int64
# dtypes: int64(3)
# memory usage: 174.0 KB

# %%
place_rank = user_rating['place_id'].value_counts().reset_index()
place_rank
# Out:
#     place_id  count
# 0         56    331
# 1         68    289
# 2         57    285
# 3         28    281
# 4         20    262
# ..       ...    ...
# 70        67      4
# 71        37      2
# 72        55      1
# 73        21      1
# 74        39      1
#
# [75 rows x 2 columns]

# %%
place_rank= pd.merge(place_rank, tourist_attraction[['place_id','name']], how='left', left_on='index', right_on='place_id')
place_rank
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13560\103223125.py in ?()
# ----> 1 place_rank= pd.merge(place_rank, tourist_attraction[['place_id','name']], how='left', left_on='index', right_on='place_id')
#       2 place_rank
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733         (
#     734             self.left_join_keys,
#     735             self.right_join_keys,
#     736             self.join_names,
# --> 737         ) = self._get_merge_keys()
#     738
#     739         # validate the merge keys dtypes. We may need to coerce
#     740         # to avoid incompatible dtypes
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1217                     if lk is not None:
#    1218                         # Then we're either Hashable or a wrong-length arraylike,
#    1219                         #  the latter of which will raise
#    1220                         lk = cast(Hashable, lk)
# -> 1221                         left_keys.append(left._get_label_or_level_values(lk))
#    1222                         join_names.append(lk)
#    1223                     else:
#    1224                         # work-around for merge_asof(left_index=True)
#
# c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'index'

# %%
# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(12, 6))
sns.barplot(x='place_id_x', y='name', data=place_rank)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=30)
plt.ylabel('Jumlah Rating')
plt.xlabel('Nama Lokasi')
plt.show()

# %%
df = user_rating.copy()
df.head()
# Out:
#    user_id  place_id  rating
# 0        5         1       4
# 1        5        12       5
# 2        5        19       4
# 3        5        45       5
# 4        5        62       4

# %%
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %%
# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('user_id')

# Mapping User_Id ke dataframe
df['user'] = df['user_id'].map(user_to_user_encoded)

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('place_id')

# Mapping Place_Id ke dataframe place
df['place'] = df['place_id'].map(place_to_place_encoded)

# %%
df
# Out:
#       user_id  place_id  rating  user  place
# 0           5         1       4     0      0
# 1           5        12       5     0      1
# 2           5        19       4     0      2
# 3           5        45       5     0      3
# 4           5        62       4     0      4
# ...       ...       ...     ...   ...    ...
# 7412    88129        75       3  1483     20
# 7413    88321        64       1  1484     25
# 7414    88321        68       4  1484     26
# 7415    88321        74       3  1484     48
# 7416    88321        75       3  1484     20
#
# [7417 rows x 5 columns]

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)

# Mengubah rating menjadi nilai float
df['rating'] = df['rating'].values.astype(np.float32)

# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['rating']), max(df['rating'])

print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 1485, Number of Place: 75, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       user_id  place_id  rating  user  place
# 5483    35151        75     5.0  1061     20
# 4556    26995        56     5.0   873     24

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values

# Membuat variabel y untuk membuat rating dari hasil
y = df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values

# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %%
class RecommenderNet(tf.keras.Model):

  def __init__(self, num_users, num_places, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_places = num_places
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding(
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1)
    self.places_embedding = layers.Embedding(
        num_places,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.places_bias = layers.Embedding(num_places, 1)

  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0])
    user_bias = self.user_bias(inputs[:, 0])
    places_vector = self.places_embedding(inputs[:, 1])
    places_bias = self.places_bias(inputs[:, 1])

    dot_user_places = tf.tensordot(user_vector, places_vector, 2)

    x = dot_user_places + user_bias + places_bias

    return tf.nn.sigmoid(x)

# %%
model = RecommenderNet(num_users, num_place, embedding_size=20)

model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    epochs = 1000,
    validation_data = (x_val, y_val),
    callbacks = [early_stopping],
    batch_size = 32
)
# Out:
# Epoch 1/1000
# 186/186 [==============================] - 5s 15ms/step - loss: 0.6767 - root_mean_squared_error: 0.4065 - val_loss: 0.6448 - val_root_mean_squared_error: 0.3881
# Epoch 2/1000
# 186/186 [==============================] - 1s 4ms/step - loss: 0.4835 - root_mean_squared_error: 0.2711 - val_loss: 0.5964 - val_root_mean_squared_error: 0.3561
# Epoch 3/1000
# 186/186 [==============================] - 1s 3ms/step - loss: 0.4221 - root_mean_squared_error: 0.2242 - val_loss: 0.5671 - val_root_mean_squared_error: 0.3358
# Epoch 4/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.4124 - root_mean_squared_error: 0.2179 - val_loss: 0.5587 - val_root_mean_squared_error: 0.3298
# Epoch 5/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.4088 - root_mean_squared_error: 0.2159 - val_loss: 0.5558 - val_root_mean_squared_error: 0.3278
# Epoch 6/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.4057 - root_mean_squared_error: 0.2138 - val_loss: 0.5526 - val_root_mean_squared_error: 0.3255
# Epoch 7/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.4013 - root_mean_squared_error: 0.2110 - val_loss: 0.5504 - val_root_mean_squared_error: 0.3240
# Epoch 8/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3994 - root_mean_squared_error: 0.2100 - val_loss: 0.5494 - val_root_mean_squared_error: 0.3234
# Epoch 9/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.3965 - root_mean_squared_error: 0.2080 - val_loss: 0.5454 - val_root_mean_squared_error: 0.3206
# Epoch 10/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3940 - root_mean_squared_error: 0.2064 - val_loss: 0.5410 - val_root_mean_squared_error: 0.3175
# Epoch 11/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3907 - root_mean_squared_error: 0.2042 - val_loss: 0.5398 - val_root_mean_squared_error: 0.3168
# Epoch 12/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3880 - root_mean_squared_error: 0.2022 - val_loss: 0.5346 - val_root_mean_squared_error: 0.3131
# Epoch 13/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3851 - root_mean_squared_error: 0.2007 - val_loss: 0.5337 - val_root_mean_squared_error: 0.3126
# Epoch 14/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3825 - root_mean_squared_error: 0.1986 - val_loss: 0.5285 - val_root_mean_squared_error: 0.3090
# Epoch 15/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3825 - root_mean_squared_error: 0.1989 - val_loss: 0.5255 - val_root_mean_squared_error: 0.3069
# Epoch 16/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3791 - root_mean_squared_error: 0.1962 - val_loss: 0.5164 - val_root_mean_squared_error: 0.3003
# Epoch 17/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3764 - root_mean_squared_error: 0.1945 - val_loss: 0.5169 - val_root_mean_squared_error: 0.3008
# Epoch 18/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3736 - root_mean_squared_error: 0.1924 - val_loss: 0.5087 - val_root_mean_squared_error: 0.2949
# Epoch 19/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3720 - root_mean_squared_error: 0.1913 - val_loss: 0.5054 - val_root_mean_squared_error: 0.2926
# Epoch 20/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3705 - root_mean_squared_error: 0.1902 - val_loss: 0.5053 - val_root_mean_squared_error: 0.2926
# Epoch 21/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3682 - root_mean_squared_error: 0.1885 - val_loss: 0.5002 - val_root_mean_squared_error: 0.2889
# Epoch 22/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3666 - root_mean_squared_error: 0.1875 - val_loss: 0.4937 - val_root_mean_squared_error: 0.2841
# Epoch 23/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3641 - root_mean_squared_error: 0.1857 - val_loss: 0.4887 - val_root_mean_squared_error: 0.2805
# Epoch 24/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3629 - root_mean_squared_error: 0.1849 - val_loss: 0.4853 - val_root_mean_squared_error: 0.2781
# Epoch 25/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3611 - root_mean_squared_error: 0.1832 - val_loss: 0.4746 - val_root_mean_squared_error: 0.2699
# Epoch 26/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3599 - root_mean_squared_error: 0.1829 - val_loss: 0.4763 - val_root_mean_squared_error: 0.2715
# Epoch 27/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3579 - root_mean_squared_error: 0.1810 - val_loss: 0.4675 - val_root_mean_squared_error: 0.2649
# Epoch 28/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3554 - root_mean_squared_error: 0.1793 - val_loss: 0.4666 - val_root_mean_squared_error: 0.2644
# Epoch 29/1000
# 186/186 [==============================] - 1s 4ms/step - loss: 0.3538 - root_mean_squared_error: 0.1779 - val_loss: 0.4629 - val_root_mean_squared_error: 0.2617
# Epoch 30/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3533 - root_mean_squared_error: 0.1778 - val_loss: 0.4637 - val_root_mean_squared_error: 0.2627
# Epoch 31/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3513 - root_mean_squared_error: 0.1763 - val_loss: 0.4632 - val_root_mean_squared_error: 0.2626
# Epoch 32/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3495 - root_mean_squared_error: 0.1740 - val_loss: 0.4550 - val_root_mean_squared_error: 0.2564
# Epoch 33/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3491 - root_mean_squared_error: 0.1748 - val_loss: 0.4603 - val_root_mean_squared_error: 0.2609
# Epoch 34/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3463 - root_mean_squared_error: 0.1723 - val_loss: 0.4542 - val_root_mean_squared_error: 0.2562
# Epoch 35/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3462 - root_mean_squared_error: 0.1724 - val_loss: 0.4515 - val_root_mean_squared_error: 0.2544
# Epoch 36/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3442 - root_mean_squared_error: 0.1704 - val_loss: 0.4457 - val_root_mean_squared_error: 0.2500
# Epoch 37/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3429 - root_mean_squared_error: 0.1703 - val_loss: 0.4515 - val_root_mean_squared_error: 0.2548
# Epoch 38/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3415 - root_mean_squared_error: 0.1685 - val_loss: 0.4457 - val_root_mean_squared_error: 0.2504
# Epoch 39/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3401 - root_mean_squared_error: 0.1671 - val_loss: 0.4400 - val_root_mean_squared_error: 0.2460
# Epoch 40/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3389 - root_mean_squared_error: 0.1663 - val_loss: 0.4393 - val_root_mean_squared_error: 0.2458
# Epoch 41/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3376 - root_mean_squared_error: 0.1654 - val_loss: 0.4361 - val_root_mean_squared_error: 0.2434
# Epoch 42/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3375 - root_mean_squared_error: 0.1652 - val_loss: 0.4355 - val_root_mean_squared_error: 0.2433
# Epoch 43/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3355 - root_mean_squared_error: 0.1644 - val_loss: 0.4390 - val_root_mean_squared_error: 0.2465
# Epoch 44/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3344 - root_mean_squared_error: 0.1626 - val_loss: 0.4281 - val_root_mean_squared_error: 0.2379
# Epoch 45/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3334 - root_mean_squared_error: 0.1624 - val_loss: 0.4309 - val_root_mean_squared_error: 0.2405
# Epoch 46/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3322 - root_mean_squared_error: 0.1608 - val_loss: 0.4255 - val_root_mean_squared_error: 0.2363
# Epoch 47/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3313 - root_mean_squared_error: 0.1605 - val_loss: 0.4273 - val_root_mean_squared_error: 0.2382
# Epoch 48/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3305 - root_mean_squared_error: 0.1602 - val_loss: 0.4256 - val_root_mean_squared_error: 0.2371
# Epoch 49/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3300 - root_mean_squared_error: 0.1593 - val_loss: 0.4233 - val_root_mean_squared_error: 0.2356
# Epoch 50/1000
# 186/186 [==============================] - 1s 5ms/step - loss: 0.3288 - root_mean_squared_error: 0.1591 - val_loss: 0.4300 - val_root_mean_squared_error: 0.2414
# Epoch 51/1000
# 186/186 [==============================] - 1s 3ms/step - loss: 0.3272 - root_mean_squared_error: 0.1562 - val_loss: 0.4185 - val_root_mean_squared_error: 0.2323
# Epoch 52/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3265 - root_mean_squared_error: 0.1570 - val_loss: 0.4212 - val_root_mean_squared_error: 0.2349
# Epoch 53/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3258 - root_mean_squared_error: 0.1557 - val_loss: 0.4127 - val_root_mean_squared_error: 0.2280
# Epoch 54/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3253 - root_mean_squared_error: 0.1560 - val_loss: 0.4192 - val_root_mean_squared_error: 0.2336
# Epoch 55/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3244 - root_mean_squared_error: 0.1553 - val_loss: 0.4148 - val_root_mean_squared_error: 0.2301
# Epoch 56/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3235 - root_mean_squared_error: 0.1541 - val_loss: 0.4132 - val_root_mean_squared_error: 0.2291
# Epoch 57/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3230 - root_mean_squared_error: 0.1538 - val_loss: 0.4127 - val_root_mean_squared_error: 0.2289
# Epoch 58/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3220 - root_mean_squared_error: 0.1531 - val_loss: 0.4107 - val_root_mean_squared_error: 0.2274
# Epoch 59/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3217 - root_mean_squared_error: 0.1527 - val_loss: 0.4103 - val_root_mean_squared_error: 0.2274
# Epoch 60/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3198 - root_mean_squared_error: 0.1509 - val_loss: 0.4075 - val_root_mean_squared_error: 0.2253
# Epoch 61/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3194 - root_mean_squared_error: 0.1509 - val_loss: 0.4102 - val_root_mean_squared_error: 0.2279
# Epoch 62/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3191 - root_mean_squared_error: 0.1507 - val_loss: 0.4100 - val_root_mean_squared_error: 0.2280
# Epoch 63/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3181 - root_mean_squared_error: 0.1502 - val_loss: 0.4098 - val_root_mean_squared_error: 0.2280
# Epoch 64/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3178 - root_mean_squared_error: 0.1498 - val_loss: 0.4091 - val_root_mean_squared_error: 0.2277
# Epoch 65/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3171 - root_mean_squared_error: 0.1492 - val_loss: 0.4072 - val_root_mean_squared_error: 0.2263
# Epoch 66/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3168 - root_mean_squared_error: 0.1491 - val_loss: 0.4074 - val_root_mean_squared_error: 0.2268
# Epoch 67/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3163 - root_mean_squared_error: 0.1486 - val_loss: 0.4065 - val_root_mean_squared_error: 0.2262
# Epoch 68/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3149 - root_mean_squared_error: 0.1476 - val_loss: 0.4086 - val_root_mean_squared_error: 0.2282
# Epoch 69/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3152 - root_mean_squared_error: 0.1477 - val_loss: 0.4059 - val_root_mean_squared_error: 0.2261
# Epoch 70/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3140 - root_mean_squared_error: 0.1467 - val_loss: 0.4082 - val_root_mean_squared_error: 0.2284
# Epoch 71/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3139 - root_mean_squared_error: 0.1469 - val_loss: 0.4062 - val_root_mean_squared_error: 0.2268
# Epoch 72/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3137 - root_mean_squared_error: 0.1466 - val_loss: 0.4056 - val_root_mean_squared_error: 0.2266
# Epoch 73/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3116 - root_mean_squared_error: 0.1446 - val_loss: 0.4069 - val_root_mean_squared_error: 0.2279
# Epoch 74/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3126 - root_mean_squared_error: 0.1460 - val_loss: 0.4043 - val_root_mean_squared_error: 0.2258
# Epoch 75/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3115 - root_mean_squared_error: 0.1450 - val_loss: 0.4061 - val_root_mean_squared_error: 0.2275
# Epoch 76/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3111 - root_mean_squared_error: 0.1447 - val_loss: 0.4020 - val_root_mean_squared_error: 0.2242
# Epoch 77/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3103 - root_mean_squared_error: 0.1438 - val_loss: 0.4036 - val_root_mean_squared_error: 0.2258
# Epoch 78/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3097 - root_mean_squared_error: 0.1436 - val_loss: 0.4071 - val_root_mean_squared_error: 0.2291
# Epoch 79/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3098 - root_mean_squared_error: 0.1439 - val_loss: 0.4015 - val_root_mean_squared_error: 0.2245
# Epoch 80/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3097 - root_mean_squared_error: 0.1433 - val_loss: 0.3994 - val_root_mean_squared_error: 0.2227
# Epoch 81/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3088 - root_mean_squared_error: 0.1433 - val_loss: 0.4020 - val_root_mean_squared_error: 0.2252
# Epoch 82/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3089 - root_mean_squared_error: 0.1431 - val_loss: 0.4007 - val_root_mean_squared_error: 0.2243
# Epoch 83/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3087 - root_mean_squared_error: 0.1430 - val_loss: 0.4012 - val_root_mean_squared_error: 0.2248
# Epoch 84/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3078 - root_mean_squared_error: 0.1425 - val_loss: 0.4017 - val_root_mean_squared_error: 0.2255
# Epoch 85/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3072 - root_mean_squared_error: 0.1414 - val_loss: 0.4012 - val_root_mean_squared_error: 0.2253
# Epoch 86/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3064 - root_mean_squared_error: 0.1408 - val_loss: 0.4032 - val_root_mean_squared_error: 0.2273
# Epoch 87/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3068 - root_mean_squared_error: 0.1419 - val_loss: 0.4043 - val_root_mean_squared_error: 0.2285
# Epoch 88/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3071 - root_mean_squared_error: 0.1422 - val_loss: 0.4004 - val_root_mean_squared_error: 0.2250
# Epoch 89/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.3066 - root_mean_squared_error: 0.1416 - val_loss: 0.4015 - val_root_mean_squared_error: 0.2262
# Epoch 90/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3057 - root_mean_squared_error: 0.1411 - val_loss: 0.3985 - val_root_mean_squared_error: 0.2235
# Epoch 91/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3053 - root_mean_squared_error: 0.1404 - val_loss: 0.3975 - val_root_mean_squared_error: 0.2226
# Epoch 92/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3044 - root_mean_squared_error: 0.1395 - val_loss: 0.4005 - val_root_mean_squared_error: 0.2255
# Epoch 93/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3045 - root_mean_squared_error: 0.1399 - val_loss: 0.4030 - val_root_mean_squared_error: 0.2279
# Epoch 94/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3042 - root_mean_squared_error: 0.1397 - val_loss: 0.4023 - val_root_mean_squared_error: 0.2273
# Epoch 95/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3048 - root_mean_squared_error: 0.1404 - val_loss: 0.3993 - val_root_mean_squared_error: 0.2246
# Epoch 96/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3041 - root_mean_squared_error: 0.1398 - val_loss: 0.4045 - val_root_mean_squared_error: 0.2294
# Epoch 97/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3041 - root_mean_squared_error: 0.1396 - val_loss: 0.3999 - val_root_mean_squared_error: 0.2252
# Epoch 98/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3033 - root_mean_squared_error: 0.1392 - val_loss: 0.3989 - val_root_mean_squared_error: 0.2244
# Epoch 99/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3033 - root_mean_squared_error: 0.1391 - val_loss: 0.4029 - val_root_mean_squared_error: 0.2281
# Epoch 100/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3022 - root_mean_squared_error: 0.1379 - val_loss: 0.4007 - val_root_mean_squared_error: 0.2261
# Epoch 101/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.3029 - root_mean_squared_error: 0.1391 - val_loss: 0.4008 - val_root_mean_squared_error: 0.2263
# Epoch 102/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.3022 - root_mean_squared_error: 0.1384 - val_loss: 0.3981 - val_root_mean_squared_error: 0.2237
# Epoch 103/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3022 - root_mean_squared_error: 0.1389 - val_loss: 0.4028 - val_root_mean_squared_error: 0.2282
# Epoch 104/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3019 - root_mean_squared_error: 0.1382 - val_loss: 0.3973 - val_root_mean_squared_error: 0.2231
# Epoch 105/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.3024 - root_mean_squared_error: 0.1387 - val_loss: 0.3984 - val_root_mean_squared_error: 0.2242
# Epoch 106/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3013 - root_mean_squared_error: 0.1380 - val_loss: 0.3998 - val_root_mean_squared_error: 0.2255
# Epoch 107/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3013 - root_mean_squared_error: 0.1377 - val_loss: 0.4024 - val_root_mean_squared_error: 0.2281
# Epoch 108/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.3006 - root_mean_squared_error: 0.1369 - val_loss: 0.4018 - val_root_mean_squared_error: 0.2275
# Epoch 109/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.3000 - root_mean_squared_error: 0.1367 - val_loss: 0.4027 - val_root_mean_squared_error: 0.2284
# Epoch 110/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.3006 - root_mean_squared_error: 0.1374 - val_loss: 0.4027 - val_root_mean_squared_error: 0.2284
# Epoch 111/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.2999 - root_mean_squared_error: 0.1369 - val_loss: 0.4022 - val_root_mean_squared_error: 0.2279
# Epoch 112/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3005 - root_mean_squared_error: 0.1377 - val_loss: 0.4025 - val_root_mean_squared_error: 0.2282
# Epoch 113/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.3001 - root_mean_squared_error: 0.1372 - val_loss: 0.4013 - val_root_mean_squared_error: 0.2270
# Epoch 114/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.2995 - root_mean_squared_error: 0.1366 - val_loss: 0.4024 - val_root_mean_squared_error: 0.2282
# Epoch 115/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.2995 - root_mean_squared_error: 0.1370 - val_loss: 0.4039 - val_root_mean_squared_error: 0.2296
# Epoch 116/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.2992 - root_mean_squared_error: 0.1360 - val_loss: 0.4002 - val_root_mean_squared_error: 0.2260
# Epoch 117/1000
# 186/186 [==============================] - 1s 6ms/step - loss: 0.2993 - root_mean_squared_error: 0.1366 - val_loss: 0.4012 - val_root_mean_squared_error: 0.2269
# Epoch 118/1000
# 186/186 [==============================] - 2s 10ms/step - loss: 0.2991 - root_mean_squared_error: 0.1366 - val_loss: 0.3997 - val_root_mean_squared_error: 0.2255
# Epoch 119/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.2991 - root_mean_squared_error: 0.1365 - val_loss: 0.4023 - val_root_mean_squared_error: 0.2278
# Epoch 120/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.2980 - root_mean_squared_error: 0.1352 - val_loss: 0.4015 - val_root_mean_squared_error: 0.2271
# Epoch 121/1000
# 186/186 [==============================] - 1s 7ms/step - loss: 0.2985 - root_mean_squared_error: 0.1360 - val_loss: 0.4011 - val_root_mean_squared_error: 0.2267
# Epoch 122/1000
# 186/186 [==============================] - 2s 8ms/step - loss: 0.2988 - root_mean_squared_error: 0.1364 - val_loss: 0.4018 - val_root_mean_squared_error: 0.2273
# Epoch 123/1000
# 186/186 [==============================] - 1s 8ms/step - loss: 0.2980 - root_mean_squared_error: 0.1357 - val_loss: 0.4033 - val_root_mean_squared_error: 0.2287
# Epoch 124/1000
# 186/186 [==============================] - 2s 9ms/step - loss: 0.2983 - root_mean_squared_error: 0.1363 - val_loss: 0.4034 - val_root_mean_squared_error: 0.2289

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "validation"], loc="upper left")
plt.show()

# %%
place_df = tourist_attraction[['place_id','name','category','rating','latitude','longitude']]
df = user_rating.copy()

# %%
place_df
# Out:
#     place_id                                    name             category  \
# 0          1                    4 Brahma Statue Arts               Patung
# 1          2             Adventure Land Romokalisari        Tujuan Wisata
# 2          3                    Alun - Alun Surabaya        Tujuan Wisata
# 3          4                             Apsari Park                Taman
# 4          5                         Arca Joko Dolog  Bangunan Bersejarah
# ..       ...                                     ...                  ...
# 70        71                      Taman Persahabatan        Taman bermain
# 71        72  Taman Pertanian Terpadu Balas Klumprik                Taman
# 72        73                 Taman Prestasi Surabaya           Taman Kota
# 73        74                           Taman Teratai                Taman
# 74        75                              Unesa Lake        Tujuan Wisata
#
#     rating  latitude   longitude
# 0      4.3 -7.247284  112.801081
# 1      4.6 -7.198610  112.664771
# 2      4.8 -7.263864  112.745306
# 3      4.6 -7.263635  112.742562
# 4      4.6 -7.264916  112.742777
# ..     ...       ...         ...
# 70     4.6 -7.276744  112.745968
# 71     4.4 -7.329670  112.691251
# 72     4.6 -7.261472  112.742828
# 73     4.4 -7.255100  112.755581
# 74     4.5 -7.301489  112.674925
#
# [75 rows x 6 columns]

# %%
# Mengambil sample user
user_id = df.user_id.sample(1).iloc[0]
place_visited_by_user = df[df.user_id == user_id]

# %%
# Membuat data lokasi yang belum dikunjungi user
place_not_visited = place_df[~place_df['place_id'].isin(place_visited_by_user.place_id.values)]['place_id']
place_not_visited = list(
    set(place_not_visited)
    .intersection(set(place_to_place_encoded.keys()))
)

place_not_visited = [[place_to_place_encoded.get(x)] for x in place_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_place_array = np.hstack(
    ([[user_encoder]] * len(place_not_visited), place_not_visited)
)

# %%
# Mengambil top 7 recommendation
ratings = model.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-7:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]

print('Daftar rekomendasi untuk: {}'.format('User ' + str(user_id)))
print('===' * 15,'\n')
print('----' * 15)
print('Tempat dengan rating wisata paling tinggi dari user')
print('----' * 15)

top_place_user = (
    place_visited_by_user.sort_values(
        by = 'rating',
        ascending=False
    )
    .head(5)
    .place_id.values
)

place_df_rows = place_df[place_df['place_id'].isin(top_place_user)]
for row in place_df_rows.itertuples():
    print(row.name, ':', row.category)

print('')
print('----' * 15)
print('Top 7 place recommendation')
print('----' * 15)

recommended_place = place_df[place_df['place_id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.name, '\n    ', row.category, ',', 'Rating Wisata ', row.rating,'\n')

print('==='*15)
# Out:
# 3/3 [==============================] - 1s 6ms/step
# Daftar rekomendasi untuk: User 20889
# =============================================
#
# ------------------------------------------------------------
# Tempat dengan rating wisata paling tinggi dari user
# ------------------------------------------------------------
# Jalan Gula Spot Foto : Tujuan Wisata
# Sanggar Agung Temple : Kuil
# Surabaya Zero Kilometer Monument : Bangunan Bersejarah
# Taman Harmoni Keputih : Taman Kota
#
# ------------------------------------------------------------
# Top 7 place recommendation
# ------------------------------------------------------------
# 1 . KidZania Surabaya
#      Taman Bermain Dalam Ruangan , Rating Wisata  4.8
#
# 2 . Kunang Kunang Park
#      Taman , Rating Wisata  4.4
#
# 3 . Makam Sunan Ampel
#      Tempat Ziarah , Rating Wisata  4.8
#
# 4 . Museum W.R. Soepratman
#      Museum , Rating Wisata  4.8
#
# 5 . Ria Beach Kenjeran
#      Tujuan Wisata , Rating Wisata  4.2
#
# 6 . Sunan Ampel Great Mosque
#      Masjid , Rating Wisata  4.8
#
# 7 . Sunan Ampel Religious Tourism Area
#      Tempat Religius , Rating Wisata  4.8
#
# =============================================

# %%
recommended_place
# Out:
#     place_id                                name                     category  \
# 20        21                   KidZania Surabaya  Taman Bermain Dalam Ruangan
# 22        23                  Kunang Kunang Park                        Taman
# 25        26                   Makam Sunan Ampel                Tempat Ziarah
# 34        35              Museum W.R. Soepratman                       Museum
# 43        44                  Ria Beach Kenjeran                Tujuan Wisata
# 46        47            Sunan Ampel Great Mosque                       Masjid
# 47        48  Sunan Ampel Religious Tourism Area              Tempat Religius
#
#     rating  latitude   longitude
# 20     4.8 -7.290551  112.706422
# 22     4.4 -7.318220  112.784240
# 25     4.8 -7.229894  112.742528
# 34     4.8 -7.250635  112.753769
# 43     4.2 -7.250916  112.800933
# 46     4.8 -7.230335  112.742906
# 47     4.8 -7.230271  112.745162

# %%
bus_route = pd.read_excel('bus_route_merged.xlsx')
bus_route
# Out:
#                                nama  latitude   longitude
# 0    Terminal Purabaya (Bungurasih) -7.352082  112.724435
# 1             Halte Dukuh Menanggal -7.343490  112.728930
# 2             Halte Kerto Menanggal -7.343523  112.729403
# 3                Halte Siwalankerto -7.337048  112.729054
# 4               Halte Taman Pelangi -7.329158  112.730918
# ..                              ...       ...         ...
# 190                 Samsat Tandes 1 -7.259950  112.688720
# 191                 Samsat Tandes 2 -7.259741  112.688796
# 192                    Margomulyo 2 -7.237190  112.682900
# 193                    Margomulyo 1 -7.237180  112.682300
# 194       Tambak Oso Wilangun (TOW) -7.217670  112.654387
#
# [195 rows x 3 columns]

# %%
from geopy.distance import geodesic

def find_nearest_bus_route(place, bus_route):
    min_distance = float('inf')
    nearest_bus_route = None

    for _, bus_route in bus_route.iterrows():
        distance = geodesic((place['latitude'], place['longitude']),
                            (bus_route['latitude'], bus_route['longitude'])).kilometers

        if distance < min_distance:
            min_distance = distance
            nearest_bus_route = bus_route

    return nearest_bus_route, min_distance

# %%
result_rows = []

for _, place in recommended_place.iterrows():
    nearest_bus_stop, distance = find_nearest_bus_route(place, bus_route)
    result_rows.append({
        'place_name': place['name'],
        'place_latitude': place['latitude'],
        'place_longitude': place['longitude'],
        'nearest_bus_stop': nearest_bus_stop['nama'],
        'bus_stop_latitude': nearest_bus_stop['latitude'],
        'bus_stop_longitude': nearest_bus_stop['longitude'],
        'distance_to_nearest_bus_stop': distance
    })

result_df = pd.DataFrame(result_rows)

# %%
result_df
# Out:
#                            place_name  place_latitude  place_longitude  \
# 0                   KidZania Surabaya       -7.290551       112.706422
# 1                  Kunang Kunang Park       -7.318220       112.784240
# 2                   Makam Sunan Ampel       -7.229894       112.742528
# 3              Museum W.R. Soepratman       -7.250635       112.753769
# 4                  Ria Beach Kenjeran       -7.250916       112.800933
# 5            Sunan Ampel Great Mosque       -7.230335       112.742906
# 6  Sunan Ampel Religious Tourism Area       -7.230271       112.745162
#
#                nearest_bus_stop  bus_stop_latitude  bus_stop_longitude  \
# 0  Halte Taman Makam Pahlawan 2          -7.288883          112.708450
# 1               Halte Pandugo 2          -7.321934          112.781181
# 2          Halte Jembatan merah          -7.235682          112.735495
# 3            Halte Sono Kembang          -7.260928          112.747773
# 4                 Halte Kenpark          -7.252737          112.796098
# 5          Halte Jembatan merah          -7.235682          112.735495
# 6          Halte Jembatan merah          -7.235682          112.735495
#
#    distance_to_nearest_bus_stop
# 0                      0.290119
# 1                      0.531803
# 2                      1.006503
# 3                      1.316905
# 4                      0.570674
# 5                      1.009716
# 6                      1.223899

# %%
recommended_tourist_attraction = result_df[['place_name', 'place_latitude','place_longitude']]
recommended_tourist_attraction
# Out:
#                            place_name  place_latitude  place_longitude
# 0                   KidZania Surabaya       -7.290551       112.706422
# 1                  Kunang Kunang Park       -7.318220       112.784240
# 2                   Makam Sunan Ampel       -7.229894       112.742528
# 3              Museum W.R. Soepratman       -7.250635       112.753769
# 4                  Ria Beach Kenjeran       -7.250916       112.800933
# 5            Sunan Ampel Great Mosque       -7.230335       112.742906
# 6  Sunan Ampel Religious Tourism Area       -7.230271       112.745162

# %%
recommended_bus_route = result_df[['nearest_bus_stop', 'bus_stop_latitude', 'bus_stop_longitude']]
recommended_bus_route
# Out:
#                nearest_bus_stop  bus_stop_latitude  bus_stop_longitude
# 0  Halte Taman Makam Pahlawan 2          -7.288883          112.708450
# 1               Halte Pandugo 2          -7.321934          112.781181
# 2          Halte Jembatan merah          -7.235682          112.735495
# 3            Halte Sono Kembang          -7.260928          112.747773
# 4                 Halte Kenpark          -7.252737          112.796098
# 5          Halte Jembatan merah          -7.235682          112.735495
# 6          Halte Jembatan merah          -7.235682          112.735495

# %%
model.save('saved_model', save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: saved_model\assets
# INFO:tensorflow:Assets written to: saved_model\assets
